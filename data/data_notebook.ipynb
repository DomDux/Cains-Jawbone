# %% [markdown]
# # Processing the data from the book
# I want to extract the words from the Cain's Jawbone paperback into text files so that I can CTRL+F as I work through them and navigate through my notes more easily.   I want to do this easily by photographing the pages of the book, storing them as `.jpg` files in a dedicated folder, and then using OCR to extract the text from these pages.
#
# I will be doing this using the `pytesseract` library and largely following code I took from this [GeeksForGeeks](https://www.geeksforgeeks.org/how-to-extract-text-from-images-with-python/) tutorial

# %%
from pathlib import Path

FOLDER_PATH = Path().absolute()
RAW_DIR = FOLDER_PATH.joinpath("raw")

# %% [markdown]
# # 1. Set up Tesseract for image processing
# Verify that tesseract is properly installed by checking a test
# On windows we may need to set the path to the executable

# %%
import shutil
import pytesseract
from pytesseract import TesseractNotFoundError
import platform
import os

def find_tesseract():
    "Search for the tesseract executable and return the path"
    # 1. Try PATH first (works on Linux/macOS and properly configured Windows)
    tesseract_path = shutil.which("tesseract")
    if tesseract_path:
        return tesseract_path

    # 2. Windows common install locations
    if platform.system() == "Windows":
        possible_paths = [
            r"C:\Program Files\Tesseract-OCR\tesseract.exe",
            r"C:\Program Files (x86)\Tesseract-OCR\tesseract.exe",
        ]
        for path in possible_paths:
            if os.path.exists(path):
                return path

    # 3. Not found
    return None


def setup_tesseract():
    "Find the tesseract executable and (if not already set) ensure the path is set"
    try:
        pytesseract.get_tesseract_version()
    except TesseractNotFoundError:
        path = find_tesseract()
        if not path:
            raise RuntimeError(
                "Tesseract not found. Install it and/or add it to PATH.\n"
                "Windows: https://github.com/tesseract-ocr/tesseract\n"
                "Then verify with: tesseract --version"
            )

        pytesseract.pytesseract.tesseract_cmd = path
        return path

# %%
from PIL import Image 
from pytesseract import pytesseract

image_path = RAW_DIR.joinpath("archive").joinpath("example_image.png") 
img = Image.open(image_path) 

setup_tesseract()
  
# Passing the image object to image_to_string() function 
# This function will extract the text from the image 
text = pytesseract.image_to_string(img) 
  
# Displaying the extracted text 
print(text)

# %%
import os
RAW_DIR = FOLDER_PATH.joinpath("raw")
images = os.listdir(RAW_DIR)
images.remove('archive')
images.sort()

print(images)

# %% [markdown]
# # 2. Perform OCR
# Execute the image processing

# %%
import numpy as np 
import cv2

def process_image_for_text(path_to_image: Path):
    img = cv2.imread(path_to_image)

    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    sharpen_kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
    sharpen = cv2.filter2D(gray, -1, sharpen_kernel)
    _, thresh = cv2.threshold(sharpen, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    # Further noise removal using morphological operations
    kernel = np.ones((1, 1), np.uint8)
    processed_img = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel)
    
    # Save the processed image to a temporary file
    temp_filename = "temp_image.png"
    cv2.imwrite(temp_filename, processed_img)

    # Use Tesseract to extract text
    custom_config = r'--oem 3 --psm 6'
    text = pytesseract.image_to_string(Image.open(temp_filename), lang='eng', config=custom_config)
        
    return text

# %%
import re
from dataclasses import dataclass

# Specify the directory where the .txt files are located
PROCESSED_PATH = FOLDER_PATH.joinpath("processed")

@dataclass
class PageTextFileMetadata:
    image_filename: str
    page_num: int

    def __init__(self, image_filename: str):
        self.image_filename = image_filename
        match = re.search(r".+?(\d+)\.jpg$", image_filename)
        if match:
            page_str = match.group(1)
            self.page = int(page_str)
        else:
            raise ValueError(f"Could not extract the correct page number for {self.image_filename}")

    @property
    def output_filename(self) -> str:
        return f"page_{self.page}.txt"

for image in images:
    metadata = PageTextFileMetadata(image)
    text = process_image_for_text(RAW_DIR.joinpath(metadata.image_filename))
    with open(PROCESSED_PATH.joinpath(metadata.output_filename), "w", encoding='utf-8') as f:
        f.write(text)
        print(f"Written file for {metadata.output_filename}")

# %% [markdown]
# # 3. Write the written contents to Excel
# We write the contents to an excel file for making quick analyses and notes

# %%
# Write the content to a file
import pandas as pd

# Create an empty DataFrame
df = pd.DataFrame(columns=['Page', 'File Name', 'Content'])

# Loop through each file in the directory
data = []
for filename in os.listdir(PROCESSED_PATH):
    if filename.endswith(".txt"):
        file_path = PROCESSED_PATH.joinpath(filename)
        match = re.search(r".+?(\d+)\.txt$", filename)
        page = match.group(1)
        
        # Read the content of the file
        try:
            with open(file_path, 'r') as file:  # , encoding='utf-8'
                content = file.read()
        except UnicodeDecodeError as e:
            print(f"Could not read file for page {page} due to encoding error: {e}")
            continue
        
        # Append the data to the DataFrame
        data.append({'Page': page, 'File Name': filename, 'Content': content})
df = pd.DataFrame(data=data).set_index("Page")

# %%
# Save the DataFrame to an Excel file
excel_file_path = FOLDER_PATH.parent.joinpath("notes.xlsx")
sheet_name = 'text_files'

# Check if the sheet already exists in the workbook
with pd.ExcelWriter(excel_file_path, engine='openpyxl') as writer:
    try:
        writer.book[sheet_name]
    except KeyError:
        # If the sheet does not exist, create it
        df.to_excel(writer, sheet_name=sheet_name, index=False)
    else:
        # If the sheet exists, update it
        existing_df = pd.read_excel(writer, sheet_name=sheet_name)
        updated_df = pd.concat([existing_df, df], ignore_index=True)
        updated_df.to_excel(writer, sheet_name=sheet_name, index=False)

print(f"Excel sheet '{sheet_name}' updated in file: {excel_file_path}")
